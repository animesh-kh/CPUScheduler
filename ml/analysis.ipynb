# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/animesh/Desktop/CPUScheduler/data/scheduling_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599258 entries, 0 to 599257
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   decision_id       599258 non-null  int64
#  1   tick              599258 non-null  int64
#  2   scheduler         599258 non-null  object
#  3   queue_length      599258 non-null  int64
#  4   reward            599258 non-null  float64
#  5   pid               599258 non-null  int64
#  6   priority          599258 non-null  int64
#  7   waiting           599258 non-null  int64
#  8   burst_count       599258 non-null  int64
#  9   avg_burst         599258 non-null  float64
#  10  time_in_system    599258 non-null  int64
#  11  was_selected      599258 non-null  int64
#  12  seed              599258 non-null  int64
#  13  arrival_prob      599258 non-null  float64
#  14  avg_burst_config  599258 non-null  int64
# dtypes: float64(3), int64(11), object(1)
# ...

# %%
dataset.describe()
# Out:
#          decision_id           tick   queue_length         reward  \
# count  599258.000000  599258.000000  599258.000000  599258.000000
# mean     4355.949304     334.192855     131.438436    -141.725846
# std      2242.367576     116.301532      66.977378      54.843697
# min         1.000000       0.000000       1.000000    -249.750000
# 25%      2523.000000     252.000000      79.000000    -185.125000
# 50%      4490.000000     355.000000     127.000000    -147.080600
# 75%      6412.000000     431.000000     184.000000    -102.718800
# max      7807.000000     499.000000     294.000000       0.000000
#
#                  pid       priority        waiting    burst_count  \
# count  599258.000000  599258.000000  599258.000000  599258.000000
# mean       94.309655       1.713798     141.725846       0.085334
# std        62.619333       1.072377     105.853147       0.392181
# min         1.000000       0.000000       0.000000       0.000000
# ...

# %%
dataset.head()
# Out:
#    decision_id  tick scheduler  queue_length  reward  pid  priority  waiting  \
# 0            1     1      FCFS             1     0.0    1         0        0
# 1            2     2      FCFS             1    -1.0    1         0        1
# 2            3     3      FCFS             2    -1.0    1         0        2
# 3            3     3      FCFS             2    -1.0    2         0        0
# 4            4     4      FCFS             1    -1.0    2         0        1
#
#    burst_count  avg_burst  time_in_system  was_selected  seed  arrival_prob  \
# 0            0        0.0               0             1    42           0.2
# 1            1        1.0               1             1    42           0.2
# 2            2        1.0               2             1    42           0.2
# 3            0        0.0               0             0    42           0.2
# 4            0        0.0               1             1    42           0.2
#
#    avg_burst_config
# 0                 3
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['waiting'], bins=50)
plt.title("Distribution of Waiting Time")
plt.show()

# %%
sns.boxplot(x='priority', y='waiting', data=df)
plt.title("Priority vs Waiting Time")
plt.show()

# %%
sns.histplot(df['avg_burst'], bins=50)
plt.title("Average Burst Distribution")
plt.show()

# %%
df['was_selected'].value_counts().plot(kind='bar')
plt.title("Process Selection Frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation only for numeric columns
corr = df.select_dtypes(include='number').corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.show()

# %%
df,info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df,info()
#
# NameError: name 'info' is not defined
